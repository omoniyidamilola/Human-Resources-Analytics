# %% [markdown]
# # Human Resources Analytics

# %% [markdown]
# ## Introduction
#
# Human Resources (HR) refers to the department within an organization responsible for managing the personnel or workforce. It is essential for ensuring that an organization has the right talent, adheres to legal and ethical standards, and fosters a positive and productive work environment. The role of Human Resources has evolved over the years to encompass strategic functions, aligning Human Resources practices with an organization's overall goals and objectives.
#
# Human Resources analytics is the application of data analysis and data visualization techniques to Human Resources data in order to gain insights and make data-driven decisions related to the workforce. It involves collecting, processing, and analyzing Human Resources data to improve Human Resources processes, talent management, and overall organizational performance.
#
# Human Resources analytics leverages data from various Human Resources functions, such as recruitment, employee engagement, performance management, compensation and benefits, and employee turnover, to answer critical questions and address challenges within an organization.
#
# The primary objectives of this Project  to clean, transform, and visualize the dataset for better decision-making.

# %% [markdown]
# ## About The Data set
#
# Columns Names and Their Description
#
# Age: Employee's age
#
# Attrition: Does the employee leave the organization
#
# Business_Travel: Frequency of employee's business trip
#
# Daily_Rate: Daily Salary rate for employees
#
# Department: Office of Employees
#
# Distance_From_Home: Distance From home in kilometers to work
#
# Education: Level of education achieved by staff
#
# Education_Field: Employee's field of study
#
# Employee_Count: Total Number of employees in the organization
#
# Environment_Satisfaction: Employee satisfaction with their working environment
#
# Gender: Employee's gender
#
# Hourly_Rate: Hourly rate for employees
#
# Job_Level: Employee's level of work
#
# Job_Role: The role of employees in the organization.
#
# Job_Satisfaction: Employee's satisfaction with their work
#
# Marital_Status: Employee's marital status
#
# Monthly_Income: Employee's monthly income
#
# Number_of_Companies_Worked: Number of companies the employee worked for.
#
# OverTime: Do employees work overtime
#
# Total_Working_Years: Total number of years the employee has worked
#
# Years_at_Company: Number of years the employees have been with the company

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load dataset
Employee = pd.read_csv('HR-Employee-Attrition.csv')

# %%
#Calling out the dataset after loading it. 
Employee
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#preview the dataset
Employee.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
Employee.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#.info() function is used to understand the data types, numbers of columns, number of rows and memory storage of the data.
Employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Summary statistics of  the dataset
Employee.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#lets get the shape of the dataset
Employee.shape
# Out:
# (1470, 35)

# %% [markdown]
# There are 1,470 rows and 35 columns in the dataset

# %%
#Check for columns label i.e listing all columns names
Employee.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Deleting redundant columns

# %%
# List of columns to drop
columns_to_drop = [
    'EmployeeNumber', 'HourlyRate', 'JobInvolvement', 'Over18', 'PercentSalaryHike',
    'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear',
    'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'
]

# Drop the columns
Employee.drop(columns_to_drop, axis=1, inplace=True)

# %%
#After removing unnecessary columns, checking for the relevant columns
Employee.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PerformanceRating',
#        'TotalWorkingYears', 'YearsAtCompany'],
#       dtype='object')

# %% [markdown]
# ### Renaming the columns

# %%
Employee.rename(columns={
    'BusinessTravel': 'Business_Travel',
    'DailyRate': 'Daily_Rate',
    'DistanceFromHome': 'Distance_From_Home',
    'EducationField': 'Education_Field',
    'EmployeeCount': 'Employee_Count',
    'EnvironmentSatisfaction': 'Environment_Satisfaction',
    'JobLevel': 'Job_Level',
    'JobRole': 'Job_Role',
    'JobSatisfaction': 'Job_Satisfaction',
    'MaritalStatus': 'Marital_Status',
    'MonthlyIncome': 'Monthly_Income',
    'MonthlyRate': 'Monthly_Rate',
    'NumCompaniesWorked': 'Number_of_Companies_Worked',
    'PerformanceRating': 'Performance_Rating',
    'TotalWorkingYears': 'Total_Working_Years',
    'YearsAtCompany': 'Years_at_Company'
}, inplace=True)

# %%
#Let call out the data set after removing unnecessary columns and renaming it. 
Employee
# Out:
#       Age Attrition    Business_Travel  Daily_Rate              Department  \
# 0      41       Yes      Travel_Rarely        1102                   Sales
# 1      49        No  Travel_Frequently         279  Research & Development
# 2      37       Yes      Travel_Rarely        1373  Research & Development
# 3      33        No  Travel_Frequently        1392  Research & Development
# 4      27        No      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36        No  Travel_Frequently         884  Research & Development
# 1466   39        No      Travel_Rarely         613  Research & Development
# 1467   27        No      Travel_Rarely         155  Research & Development
# 1468   49        No  Travel_Frequently        1023                   Sales
# 1469   34        No      Travel_Rarely         628  Research & Development
#
# ...

# %% [markdown]
# ### Dropping duplicates

# %%
#Checking if there is duplicate values
Employee.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %% [markdown]
# There is no duplicate in the dataset

# %% [markdown]
# ### Remove Null values

# %%
Employee.isna()
# Out:
#         Age  Attrition  Business_Travel  Daily_Rate  Department  \
# 0     False      False            False       False       False
# 1     False      False            False       False       False
# 2     False      False            False       False       False
# 3     False      False            False       False       False
# 4     False      False            False       False       False
# ...     ...        ...              ...         ...         ...
# 1465  False      False            False       False       False
# 1466  False      False            False       False       False
# 1467  False      False            False       False       False
# 1468  False      False            False       False       False
# 1469  False      False            False       False       False
#
#       Distance_From_Home  Education  Education_Field  Employee_Count  \
# 0                  False      False            False           False
# ...

# %% [markdown]
# There is no null values

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Total Number of Employee

# %%
Employee.Employee_Count.count()
# Out:
# 1470

# %% [markdown]
# There are 1,470 employees in the organization

# %% [markdown]
# ### Attrition

# %%
Employee['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#Employee Attrition

Attrition= Employee['Attrition'].value_counts()
label = Attrition.index
sizes = Attrition.values
color = ['Green', 'Red']


font1= {'family':'serif', 'color':'red', 'size':10}
font2= {'family':'serif', 'color':'purple', 'size':15}

plt.figure(figsize = (4,6))
plt.pie(Attrition, labels = label, autopct = '%1.1f%%', startangle = 90, colors = color,shadow = True)
plt.title('Employee Attrition', fontdict=font1)
plt.legend(title = 'Attrition', loc = 'best')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### 83.9% of employees did not quit the organization while 16% did leave the organization.

# %% [markdown]
# ### Business Travel

# %%
Employee['Business_Travel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: Business_Travel, dtype: int64

# %%
#Business Travel

sns.countplot(x = 'Business_Travel',data= Employee)

font1= {'family':'serif', 'color':'black', 'size':15}
font2= {'family':'serif', 'color':'red', 'size':15}

plt.title('Business Travel', fontdict=font1)
plt.xlabel('Business Travel', fontdict=font2)
plt.ylabel('counts', fontdict=font2)
plt.show()

# %%
#Business Travel by Attrition

plt.figure(figsize=(10, 6))  
sns.countplot(data=Employee, x='Business_Travel', hue='Attrition', palette='Set2')
plt.xlabel('Business Travel')
plt.ylabel('Count')
plt.title('Business Travel by Attrition')
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

plt.show()

# %% [markdown]
# #### Most of the employees in the organization Travel Rarely, Lowest number of employee attrition is among Non_Travel while highest number is by those that Travel_Rarely

# %% [markdown]
# ### Marital Status

# %%
Employee['Marital_Status'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: Marital_Status, dtype: int64

# %%
#Marital Status of Employee

Marital_Status= Employee['Marital_Status'].value_counts()
label = Marital_Status.index
sizes = Marital_Status.values
color = ['magenta', 'orange', 'Red']


font1= {'family':'serif', 'color':'red', 'size':10}
font2= {'family':'serif', 'color':'purple', 'size':15}

plt.figure(figsize = (4,6))
plt.pie(Marital_Status, labels = label, autopct = '%1.1f%%', startangle = 90, colors = color,shadow = True)
plt.title('Marital Status Of Employee', fontdict=font1)
plt.legend(title = 'Marital_Status', loc = 'best')
plt.axis('equal')
plt.show()

# %%
#Marital Status by Attrition

plt.figure(figsize=(10, 6))  
sns.countplot(data=Employee, x='Marital_Status', hue='Attrition', palette='Set2')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.title('Marital Status by Attrition')
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

plt.show()

# %% [markdown]
# #### Most of the employees are married in the organization. Attrition rate is low for employees that are divorced

# %% [markdown]
# ### Job Role

# %%
Employee['Job_Role'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: Job_Role, dtype: int64

# %% [markdown]
# #### Sales Executive and Research Scientist are the Job positions with the highest number of employees.

# %% [markdown]
# ### Average Monthly Income By Job Role

# %%
Employee.groupby('Job_Role')['Monthly_Income'].mean()
# Out:
# Job_Role
# Healthcare Representative     7528.763359
# Human Resources               4235.750000
# Laboratory Technician         3237.169884
# Manager                      17181.676471
# Manufacturing Director        7295.137931
# Research Director            16033.550000
# Research Scientist            3239.972603
# Sales Executive               6924.279141
# Sales Representative          2626.000000
# Name: Monthly_Income, dtype: float64

# %%
#Average Monthly Income by Job Role

income_by_job_role = Employee.groupby('Job_Role')['Monthly_Income'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(12, 6)) 
plt.barh(income_by_job_role['Job_Role'], income_by_job_role['Monthly_Income'], color='plum')
plt.xlabel('Avearge Monthly Income')
plt.ylabel('Job Role')
plt.title('Average Monthly Income by Job Role')
plt.gca().invert_yaxis()  
plt.show()

# %% [markdown]
# #### Managers and Research Directors have the highest monthly income on average.

# %% [markdown]
# ### Which Job Role has the highest Attrition Rate? Which Job Role has the lowest Attrition Rate.

# %%
#Which Job Role has the highest Attrition Rate? Which Job Role has the lowest Attrition Rate.

plt.figure(figsize=(10, 6)) 
sns.countplot(data=Employee, x='Job_Role', hue='Attrition', palette='Set2')
plt.xticks(rotation=90)
plt.xlabel('Job Role')
plt.ylabel('Count')
plt.title('Job Role by Attrition')
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

plt.show()

# %% [markdown]
# #### Sales Executives, Research Scientist and Laboratory Technician are the 3 top Job Roles with the highest attrition rate while Research Director, Manager and Sales Representative has the lowest Attrition rate

# %% [markdown]
# ### Over Time

# %%
Employee['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# ### Relationship between OverTime and Age

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.boxplot(data=Employee, x='Age', y='OverTime', palette='Set3')
plt.xlabel('Age')
plt.ylabel('OverTime')
plt.title('OverTime by Age')

plt.xticks(rotation=90)  

plt.show()

# %% [markdown]
# #### Most of the employees that did overtime are between age 30 - 40.

# %%
#Attrition by Age

age_bins = [20, 30, 40, 50, 60, 70]
age_labels = ['20-29', '30-39', '40-49', '50-59', '60+']

Employee['Age_Group'] = pd.cut(Employee['Age'], bins=age_bins, labels=age_labels)

plt.figure(figsize=(10, 6)) 
sns.countplot(data=Employee, x='Age_Group', hue='Attrition', palette='Set2')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Attrition by Age')
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

plt.xticks(rotation=0)

plt.show()

# %% [markdown]
# ### Gender

# %%
Employee['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
#Gender of Employee

Gender = Employee['Gender'].value_counts()
label = Gender.index
sizes = Gender.values
color = ['Blue', 'Pink']


font1= {'family':'serif', 'color':'red', 'size':10}
font2= {'family':'serif', 'color':'purple', 'size':15}

plt.figure(figsize = (4,6))
plt.pie(Gender, labels = label, autopct = '%1.1f%%', startangle = 90, colors = color,shadow = True)
plt.title('Gender Of Employee', fontdict=font1)
plt.legend(title = 'Gender', loc = 'best')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### The number of male employees in the organization is higher than female employees by more than 20%.

# %% [markdown]
# ### Are there any Gender Disparities in Income

# %%
#Monthly Income by Gender

plt.figure(figsize=(8, 6)) 
sns.boxplot(data=Employee, x='Gender', y='Monthly_Income', palette='Set2')
plt.xlabel('Gender')
plt.ylabel('Monthly Income')
plt.title('Monthly Income by Gender')

plt.show()

# %%
#Gender by Attrition

plt.figure(figsize=(10, 6))  
sns.countplot(data=Employee, x='Gender', hue='Attrition', palette='Set2')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender by Attrition')
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

plt.show()

# %% [markdown]
# #### Male employees are leaving the company more compared to female employees this could be because of the gender disparities by monthly income.

# %% [markdown]
# ### Department

# %%
Employee['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
#Department by Attrition

plt.figure(figsize=(10, 5))

font1= {'family':'serif', 'color':'black', 'size':15}
font2= {'family':'serif', 'color':'red', 'size':15}

ax = sns.countplot(data=Employee, x='Department', hue='Attrition', palette='Set2')
ax.set_title('Department By Attrition')

plt.show()

# %% [markdown]
# #### Most of the employees are from Research & Development Department. Human Resources attrition rate is very low while Research & Development Department is high

# %% [markdown]
# ### Education Field

# %%
Employee['Education_Field'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: Education_Field, dtype: int64

# %%
#Education Field by Attrition

plt.figure(figsize=(10, 5))

font1= {'family':'serif', 'color':'black', 'size':15}
font2= {'family':'serif', 'color':'red', 'size':15}

sns.set_palette('Set2')  
ax = sns.countplot(data=Employee, x='Education_Field', hue='Attrition')
ax.set_title('Education Field By Attrition')
plt.xticks(rotation=90)  

plt.show()

# %% [markdown]
# #### Most of the employees are either from Life Sciences or Medical. Very Few are from Human Resources. Life Science, Medicaland Marketing have high attrition rate.

# %% [markdown]
# ### Job Satisfaction

# %%
#Job Satifaction by Attrition

satisfaction_labels = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}


Employee['Job_Satisfaction'] = Employee['Job_Satisfaction'].map(satisfaction_labels)

plt.figure(figsize=(8, 6))  
sns.countplot(data=Employee, x='Job_Satisfaction', hue='Attrition', palette='Set2')
plt.xlabel('Job Satisfaction')
plt.ylabel('Count')
plt.title('Job Satisfaction by Attrition')
plt.legend(title='Attrition', loc='upper right', labels=['No', 'Yes'])

plt.show()

# %% [markdown]
# ### Plotting a correlation map for all numeric variables to understand the relationships between numeric variables.

# %%
correlation_matrix = Employee.corr(numeric_only=True)
# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Display the heatmap
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# #### Some variables that are more related to the target variable Attrition: Environment_Satisfaction, Job_Level, Job_Satisfaction, Monthly_Income, Total_Working_Years, Years_at_Company. It shows that the categorical variables that was transformed do show a relationship with the target variable.

# %% [markdown]
# ### Total Working Years

# %%
#Monthly Income by Total Working Years

plt.figure(figsize=(8, 6))  
plt.scatter(Employee['Total_Working_Years'], Employee['Monthly_Income'], alpha=0.5, color='green')
plt.xlabel('Total Working Years')
plt.ylabel('Monthly Income')
plt.title('Monthly Income by Total Working Years')
plt.grid(True)

plt.show()

# %% [markdown]
# #### The higher the Total Working Years the higher the monthly income of an Employee. Experience is required at work

# %%
#Attrition by Total Working Years

plt.figure(figsize=(10, 6))  
sns.boxplot(data=Employee, x='Total_Working_Years', y='Attrition', palette='Set2')
plt.xlabel('Attrition')
plt.ylabel('Total Working Years')
plt.title('Attrition by Total Working Years')

plt.show()

# %% [markdown]
# #### Employees with little experience leave the company in a short time while employees with more experience stay for long periods.

# %% [markdown]
# ### Distance From Home

# %%
Employee['Distance_From_Home_KM'] = Employee['Distance_From_Home'] * 1.60934

print(Employee[['Job_Role', 'Distance_From_Home', 'Distance_From_Home_KM']])
# Out:
#                        Job_Role  Distance_From_Home  Distance_From_Home_KM
# 0               Sales Executive                   1                1.60934
# 1            Research Scientist                   8               12.87472
# 2         Laboratory Technician                   2                3.21868
# 3            Research Scientist                   3                4.82802
# 4         Laboratory Technician                   2                3.21868
# ...                         ...                 ...                    ...
# 1465      Laboratory Technician                  23               37.01482
# 1466  Healthcare Representative                   6                9.65604
# 1467     Manufacturing Director                   4                6.43736
# 1468            Sales Executive                   2                3.21868
# 1469      Laboratory Technician                   8               12.87472
#
# [1470 rows x 3 columns]

# %%
#Distance From Home (KM) by Job Role

plt.figure(figsize=(12, 6))  
sns.barplot(data=Employee, x='Job_Role', y='Distance_From_Home_KM', palette='viridis')
plt.xlabel('Job Role')
plt.ylabel('Distance From Home (KM)')
plt.title('Distance From Home (KM) by Job Role')

plt.xticks(rotation=90)  

plt.show()

# %% [markdown]
# #### Most of the employees works close to the company

# %% [markdown]
# ### Number of Companies Worked

# %%
companies_worked_by_education = Employee.groupby('Education_Field')['Number_of_Companies_Worked'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.barplot(data=companies_worked_by_education, x='Education_Field', y='Number_of_Companies_Worked', palette='viridis')
plt.xlabel('Education Field')
plt.ylabel('Number of Companies Worked')
plt.title('Number of Companies Worked by Education Field')


plt.show()

# %% [markdown]
# #### Human Resources and Medical have worked more for other companies compared to the other Education Field.

# %% [markdown]
# ## Recommendations
#
# Attrition Analysis: Conduct further analysis to understand the specific factors contributing to attrition, such as exit interviews and surveys. Identify root causes and areas for improvement.
#
# Employee Engagement: Focus on improving factors related to job satisfaction and environment satisfaction. This can involve addressing workload, career development, and workplace culture.
#
# Retention Strategies: Develop tailored retention strategies for different departments and job levels. Consider mentorship programs, career progression plans, and rewards for long-serving employees.
#
# Gender Pay Equity: Evaluate and address gender pay disparities to ensure fairness and reduce male attrition. Implement policies that promote diversity and inclusion.
#
# Age-Based Initiatives: Implement initiatives that cater to the needs and aspirations of mid-career professionals, such as training programs, leadership opportunities, and flexible work arrangements.
#
# Education Fields: Investigate the reasons behind high attrition in Life Sciences, Medical, and Marketing fields. Implement measures to improve job satisfaction and career development in these areas.
#
# Marital Status Analysis: Understand the factors contributing to low attrition among divorced employees. Implement strategies to support employees in different marital statuses.
#
# Business Travel Policies: Review and optimize business travel policies to minimize employee burnout and improve work-life balance.
#
# Retention Programs: Develop employee retention programs that align with the specific needs and expectations of different departments.
#
# Continuous Monitoring: Continuously monitor attrition rates and employee feedback to adjust strategies and ensure long-term retention success.

# %% [markdown]
# ### Limitations
#
# The analysis is based on the available dataset and may not capture all possible factors influencing employee attrition.
#
# Insights from the dataset may apply to the organization, they may not necessarily apply to other industries or contexts.
